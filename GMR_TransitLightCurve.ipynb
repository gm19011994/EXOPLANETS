# %% [markdown]
# Author: Gonzalo Marrero Ramallo
# Date: 03-05-23

# %% [markdown]
# # 2.1 Transit light curve analysis of WASP-12b
#
# ### Universidad de La Laguna Exo & Exo 2023 exercise 2
#
# Author: [Hannu Parviainen](mailto:hannu@iac.es)<br>
# Last updated: 17.4.2023

# %% [markdown]
# ## Initiation packages

# %%
pip install pytransit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytransit
#   Downloading PyTransit-2.5.23-py3-none-any.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 55.8 MB/s eta 0:00:00
# Requirement already satisfied: tables in /usr/local/lib/python3.10/dist-packages (from pytransit) (3.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from pytransit) (0.56.4)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from pytransit) (0.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytransit) (1.22.4)
# Collecting uncertainties
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pytransit) (1.5.3)
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pytransit) (1.10.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pytransit) (2022.12.0)
# Collecting pyrr
#   Downloading pyrr-0.10.3-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pytransit) (1.14.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->pytransit) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->pytransit) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pytransit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pytransit) (2022.7.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from pyrr->pytransit) (0.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn->pytransit) (3.7.1)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables->pytransit) (2.0.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables->pytransit) (2.8.4)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables->pytransit) (0.29.34)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tables->pytransit) (23.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables->pytransit) (9.0.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from uncertainties->pytransit) (0.18.3)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2~=2.0.0->tables->pytransit) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->pytransit) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pytransit) (1.16.0)
# Installing collected packages: uncertainties, semantic-version, deprecated, pyrr, pytransit
# Successfully installed deprecated-1.2.13 pyrr-0.10.3 pytransit-2.5.23 semantic-version-2.10.0 uncertainties-3.1.7

# %%
pip install corner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting corner
#   Downloading corner-2.2.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.10/dist-packages (from corner) (3.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (4.39.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.16.0)
# Installing collected packages: corner
# Successfully installed corner-2.2.2

# %%
pip install arviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: arviz in /usr/local/lib/python3.10/dist-packages (0.15.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (1.10.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (4.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from arviz) (23.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (1.22.4)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from arviz) (1.1.0)
# Requirement already satisfied: xarray>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (2022.12.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.10/dist-packages (from arviz) (0.5.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (1.5.3)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.10/dist-packages (from arviz) (67.7.2)
# Requirement already satisfied: matplotlib>=3.2 in /usr/local/lib/python3.10/dist-packages (from arviz) (3.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5netcdf>=1.0.2->arviz) (3.8.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->arviz) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2->arviz) (1.16.0)

# %%
pip install colorcet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from colorcet) (0.5.0)
# Requirement already satisfied: param>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pyct>=0.4.4->colorcet) (1.13.0)

# %%
pip install celerite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting celerite
#   Downloading celerite-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from celerite) (1.22.4)
# Installing collected packages: celerite
# Successfully installed celerite-0.4.2

# %%
pip install emcee
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emcee
#   Downloading emcee-3.1.4-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from emcee) (1.22.4)
# Installing collected packages: emcee
# Successfully installed emcee-3.1.4

# %% [markdown]
# ## Initialisation

# %%
# %matplotlib inline

# %%
import math as mt
import pandas as pd
import warnings
import seaborn as sb

from matplotlib.pyplot import subplots, setp, rc, Rectangle
from numpy import argmax, array, median, seterr, floor, percentile
from numpy.random import seed, permutation
from astropy.table import Table
from corner import corner

from pytransit import TransitLPF

seterr('ignore')
seed(0)

# %% [markdown]
# ### Read in the data
#
# First we need to read in the light curve stored in ``wasp-12b_181227_chromatic_k.fits``. The file has light curves for a single transit observed simultaneously in four passbands (g, r, i, and z_s), but we keep things simple and use only the r-band data.
#
# In our case, the photometry is saved as binary table extensions in the fits file, one extension per passband. To get the r-band data, we need to read the third HDU of the fits file (the first is the primary HDU, the second the first extension, etc.).
#
# We start the same way as with the RV data and take a look at our data and try plotting it.

# %%
tb = Table.read('wasp-12b_181227_chromatic_k.fits', 2)
tb[:5]
# Out:
# <Table length=5>
#      time_bjd             flux        ...      baseline       model
#      float64            float64       ...      float64       float64
# ------------------ ------------------ ... ------------------ -------
#  2458480.557361179 1.0001350941062013 ... 1.0161455054219737     1.0
#  2458480.558397079 1.0000222850175708 ... 1.0166937176717874     1.0
# 2458480.5587828704  0.999633046547194 ...  1.016655903207277     1.0
# 2458480.5594445122 1.0004227218395325 ...  1.016500620116942     1.0
# 2458480.5602084063 0.9981259684100012 ... 1.0165352954577924     1.0

# %% [markdown]
# Now, we can assume the time data is stored in the ``time_bjd`` column and the flux the ``flux`` column. In general, if you'd see a file like this, you should check the file's documentation (if such exists) what column is what, or ask the person who created the file.

# %%
tref = floor(tb['time_bjd'].mean())
fig, ax = subplots(figsize=(13,5), sharey=True)
ax.plot(tb['time_bjd'] - tref, tb['flux'], drawstyle='steps-mid')
setp(ax, xlabel=f"Time - {tref:.0f} [BJD]", ylabel='Normalised flux', xlim=tb['time_bjd'][[0,-1]]-tref)
fig.tight_layout()

# %% [markdown]
# ## Parameter estimation
#
# First, we create an instance of the log posterior function with the redmost light curve data.
#
# Next, we run the *DE* optimiser for ``de_iter`` iterations to clump the parameter vector population close to the global posterior maximum, use the *DE* population to initialise the *emcee* sampler, and run the sampler for ``mc_iter`` iterations to obtain a posterior sample.

# %% [markdown]
# ### Initialise the LPF and set the priors

# %%
lpf = TransitLPF('WASP-12b', 'r', tb['time_bjd'], tb['flux'])
lpf.ps
# Out:
# [  0 |G| tc             N(μ = 0.0, σ = 0.1)                      [    -inf ..      inf],
#    1 |G| p              N(μ = 1.0, σ = 1e-05)                    [    0.00 ..      inf],
#    2 |G| rho            U(a = 0.1, b = 25.0)                     [    0.00 ..      inf],
#    3 |G| b              U(a = 0.0, b = 1.0)                      [    0.00 ..     1.00],
#    4 |P| k2             U(a = 0.0025, b = 0.04)                  [    0.00 ..      inf],
#    5 |P| q1_r           U(a = 0, b = 1)                          [    0.00 ..     1.00],
#    6 |P| q2_r           U(a = 0, b = 1)                          [    0.00 ..     1.00],
#    7 |L| wn_loge_0      U(a = -4, b = 0)                         [    -inf ..      inf]]

# %%
lpf.set_prior('tc', 'NP', 2458480.65, 0.02)
lpf.set_prior('p', 'NP', 1.0914201, 1.1e-09)

# %%
lpf.ps
# Out:
# [  0 |G| tc             N(μ = 2458480.65, σ = 0.02)              [    -inf ..      inf],
#    1 |G| p              N(μ = 1.0914201, σ = 1.1e-09)            [    0.00 ..      inf],
#    2 |G| rho            U(a = 0.1, b = 25.0)                     [    0.00 ..      inf],
#    3 |G| b              U(a = 0.0, b = 1.0)                      [    0.00 ..     1.00],
#    4 |P| k2             U(a = 0.0025, b = 0.04)                  [    0.00 ..      inf],
#    5 |P| q1_r           U(a = 0, b = 1)                          [    0.00 ..     1.00],
#    6 |P| q2_r           U(a = 0, b = 1)                          [    0.00 ..     1.00],
#    7 |L| wn_loge_0      U(a = -4, b = 0)                         [    -inf ..      inf]]

# %%
lpf.optimize_global(niter=500, npop=50)
# Out:
# Global optimisation:   0%|          | 0/500 [00:00<?, ?it/s]

# %%
lpf.plot_light_curve();

# %%
lpf.sample_mcmc(5000, thin=20, repeats=2, label='MCMC sampling')
# Out:
# MCMC sampling:   0%|          | 0/2 [00:00<?, ?it/s]
# Run 1/2:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 2/2:   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
lpf.plot_light_curve('mc');

# %% [markdown]
# ### Analysis: overview
#
# The MCMC chains are now stored in ``lpf.sampler.chain``. Let's first have a look into how the chain populations evolved to see if we have any problems with our setup, whether we have converged to sample the true posterior distribution, and, if so, what was the burn-in time.

# %%
fig, axs = subplots(2,4, figsize=(13,5), sharex=True)
ls, lc = ['-','--','--'], ['k', '0.5', '0.5']
percs = [percentile(lpf.sampler.chain[:,:,i], [50,16,84], 0) for i in range(8)]
[axs.flat[i].plot(lpf.sampler.chain[:,:,i].T, 'k', alpha=0.01) for i in range(8)]
[[axs.flat[i].plot(percs[i][j], c=lc[j], ls=ls[j]) for j in range(3)] for i in range(8)]
setp(axs, yticks=[], xlim=[0,5000//20])
fig.tight_layout()

# %% [markdown]
# Ok, everything looks good. The 16th, 50th and 84th percentiles of the parameter vector population are stable and don't show any significant long-term trends. Now we can flatten the individual chains into one long chain ``fc`` and calculate the median parameter vector.

# %%
fc = lpf.sampler.chain.reshape([-1,lpf.sampler.chain.shape[-1]])
mp = median(fc, 0)

# %% [markdown]
# Let's also plot the model and the data to see if this all makes sense. To do this, we calculate the conditional distribution of flux using the posterior samples (here, we're using a random subset of samples, although this isn't really necessary), and plot the distribution median and it's median-centred 68%, 95%, and 99.7% central posterior intervals (corresponding approximately to 1, 2, and 3 intervals if the distribution is normal).

# %%
flux_pr = lpf.flux_model(fc[permutation(fc.shape[0])[:1000]])
flux_pc = array(percentile(flux_pr, [50, 0.15,99.85, 2.5,97.5, 16,84], 0))

# %%
zx1,zx2,zy1,zy2 = 0.69,0.71, 0.983, 0.992
tref = floor(lpf.timea.min())
fig, ax = subplots(1,1, figsize=(13,4))
ax.errorbar(lpf.timea-tref, lpf.ofluxa, 10**mp[7], fmt='.', c='C1', alpha=0.75)
[ax.fill_between(lpf.timea-tref,*flux_pc[i:i+2,:],alpha=0.2,facecolor='C0') for i in range(1,6,2)]
ax.plot(lpf.timea-tref, flux_pc[0], c='C0')
setp(ax, xlim=lpf.timea[[0,-1]]-tref, xlabel=f'Time - {tref:.0f} [BJD]', ylabel='Normalised flux')
fig.tight_layout()

az = fig.add_axes([0.075,0.18,0.20,0.46])
ax.add_patch(Rectangle((zx1,zy1),zx2-zx1,zy2-zy1,fill=False,edgecolor='k',lw=1,ls='dashed'))
[az.fill_between(lpf.timea-tref,*flux_pc[i:i+2,:],alpha=0.2,facecolor='C0') for i in range(1,6,2)]
setp(az, xlim=(zx1,zx2), ylim=(zy1,zy2), yticks=[], xticks=[])
az.plot(lpf.timea-tref, flux_pc[0], c='C0');

# %% [markdown]
# We could (should) also plot the residuals, but I've left them out from the plot for clarity. The plot looks fine, and we can continue to have a look at the parameter estimates.

# %% [markdown]
# ## Analysis

# %% [markdown]
# We start the analysis by making a Pandas data frame df, using the df.describe to gen an overview of the estimates, and plotting the posteriors for the most interesting parameters as violin plots.

# %%
pd.set_option('display.precision',4)
df = lpf.posterior_samples(derived_parameters=True)
df.describe()
# Out:
#                tc           p         rho           b          k2        q1_r  \
# count  1.2500e+04  1.2500e+04  12500.0000  12500.0000  12500.0000  12500.0000
# mean   2.4585e+06  1.0914e+00      0.4363      0.3328      0.0139      0.3202
# std    1.6235e-04  1.1004e-09      0.0363      0.1202      0.0004      0.1929
# min    2.4585e+06  1.0914e+00      0.3304      0.0004      0.0126      0.0443
# 25%    2.4585e+06  1.0914e+00      0.4095      0.2659      0.0136      0.1672
# 50%    2.4585e+06  1.0914e+00      0.4336      0.3650      0.0140      0.2754
# 75%    2.4585e+06  1.0914e+00      0.4628      0.4221      0.0143      0.4236
# max    2.4585e+06  1.0914e+00      0.5296      0.5698      0.0152      0.9999
#
#              q2_r   wn_loge_0           k           a         inc         t14  \
# count  12500.0000  12500.0000  12500.0000  12500.0000  12500.0000  12500.0000
# mean       0.3357     -3.0411      0.1181      3.0153      1.4590      0.1258
# std        0.2354      0.0193      0.0019      0.0836      0.0425      0.0009
# min        0.0002     -3.1155      0.1121      2.7504      1.3621      0.1223
# 25%        0.1520     -3.0543      0.1167      2.9543      1.4275      0.1251
# 50%        0.2742     -3.0414      0.1183      3.0112      1.4493      0.1257
# 75%        0.4730     -3.0283      0.1195      3.0773      1.4842      0.1264
# max        0.9999     -2.9672      0.1232      3.2188      1.5707      0.1300
#
#               t23
# count  12500.0000
# mean       0.0947
# std        0.0025
# min        0.0866
# 25%        0.0928
# 50%        0.0945
# 75%        0.0967
# max        0.1015

# %%
df.tc.hist(bins=50)
# Out:
# <Axes: >

# %%
fig, axs = subplots(1,4, figsize=(13,3))
pars = 'tc rho b k'.split()
[sb.violinplot(y=df[p], inner='quartile', ax=axs.flat[i]) for i,p in enumerate(pars)]
[axs.flat[i].text(0.05,0.9, p, transform=axs.flat[i].transAxes) for i,p in enumerate(pars)]
setp(axs, xticks=[], ylabel='')
fig.tight_layout()

# %% [markdown]
# While we're at it, let's plot some correlation plots. The limb darkening coefficients are correlated, and we'd also expect to see a correlation between the impact parameter and radius ratio.

# %%
ccols = ['k', 'rho', 'b', 'q1_r', 'q2_r']
corner(df[ccols], labels=ccols);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# ### <span style="color:darkblue">Questions and exercises</span>

# %% [markdown]
# 1. Estimate the radius of the planet using the planet-star radius ratio (k) and the stellar radius (that you need to find from somewhere ;)) Give the answer in Jupiter radii.

# %% [markdown]
# Answer:

# %%
import numpy as np #Numpy package is imported

# %%
#Define the variables:
R_earth = 6371000 #m Source: https://es.wikipedia.org/wiki/Tierra
R_sun = 6.96E8 #m Source: https://es.wikipedia.org/wiki/Sol
R_Jupiter = 69911000 #m  Source: https://es.wikipedia.org/wiki/Radio_de_J%C3%BApiter
R_star = 1.57*R_sun #m Souce: https://es.wikipedia.org/wiki/WASP-12
K = np.mean(df.k) #The mean value for K is calculated
Rplanet = K*R_star #The planet radii is calculated with the relation between K and the star radii.
Rp = Rplanet/R_Jupiter #It is calculated in Jupiter raidii.
print('The planet radii is', "{:.2f}".format(Rp), 'Jupiter radii')
# Out:
# The planet radii is 1.85 Jupiter radii

# %% [markdown]
# 2. Compare the stellar density ($ρ$) estimated from the transit modelling to the theoretical stellar density for a WASP-12-like star.

# %% [markdown]
# Answer:

# %%
rho_sun = 1.408 #g/cm3 The solar density is considered as a good aproximation, for theoretical stellar density for WASP-12-like star. Source: https://es.wikipedia.org/wiki/WASP-12
rho_star = df.rho #The densitity data is read. 
r = (np.mean(rho_star/rho_sun)) #The ratio for star density related to solar density is calculated as an average.
print('The density ratio between the WASP-12 is', "{:.2f}".format(r)) #The average value is calculated.
# Out:
# The density ratio between the WASP-12 is 0.31

# %% [markdown]
# 3. From the plot above you can see that many of the parameters are correlated with each other. What does this mean in practice?

# %% [markdown]
# Answer: This model cannot provide us independent values for our parameters. The model only show the relation between the diferent parameters. In this way, it can be estimated in practise using this correlation and see how this parameters behave.
